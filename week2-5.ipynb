# %% [markdown]
# # Lack of robustness of markowitz procedure and about using the gmv

# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
# %matplotlib inline
import edhec_risk_kit as erk
ind= erk.get_ind_returns()
er=erk.annualize_rets(ind["1996":"2000"],12)
cov=ind["1996":"2000"].cov()

# %%
erk.plot_ef(30,er,cov,show_cml=True,riskfree_rate=0.1,show_ew=True)

# %% [markdown]
# # The golden dot is the equally weighted portfolio

# %%
erk.plot_ef(30,er,cov,show_cml=True,riskfree_rate=0.1,show_ew=True,show_gmv=True)

# %% [markdown]
# ## The blue dot now is the GMV portfolio. If you check the gmv function, you will find that we give a fake expected returns vector because gmv doesn't depend on expected returns. In this case, i have given all 1s as returns.
