# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
# %matplotlib inline
import edhec_risk_kit as erk
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ind= erk.get_hfi_returns()

# %%
erk.var_gaussian(ind["2000":]['Distressed Securities'],level=1)
# Out:
# 0.03143017693928047

# %%
erk.var_gaussian(ind["2000":]['Distressed Securities'],level=1,modified=True)
# Out:
# 0.04966909110627918

# %%
erk.var_historic(ind["2000":]["Distressed Securities"],level=1)
# Out:
# 0.042642

# %%
perf= erk.get_ind_returns()["2013":"2017"]
er=erk.annualize_rets(perf,12)

# %%
perf
# Out:
#            Food    Beer   Smoke   Games  ...   Rtail   Meals     Fin   Other
# 2013-01  0.0554  0.0507  0.0561  0.1313  ...  0.0541  0.0523  0.0632  0.0720
# 2013-02  0.0384  0.0522  0.0221  0.0000  ...  0.0061  0.0070  0.0129  0.0443
# 2013-03  0.0656  0.0531  0.0272  0.0769  ...  0.0477  0.0550  0.0453  0.0228
# 2013-04  0.0284  0.0355  0.0440  0.0451  ...  0.0320  0.0240  0.0157  0.0074
# 2013-05 -0.0345 -0.0147 -0.0298  0.0218  ...  0.0239 -0.0030  0.0708  0.0590
# 2013-06  0.0084  0.0093 -0.0226 -0.0375  ... -0.0043  0.0161 -0.0043 -0.0113
# 2013-07  0.0326  0.0273  0.0176  0.0478  ...  0.0639  0.0317  0.0633  0.0434
# 2013-08 -0.0375 -0.0386 -0.0485  0.0247  ... -0.0486 -0.0229 -0.0419 -0.0381
# 2013-09  0.0031  0.0134  0.0428  0.0991  ...  0.0443  0.0401  0.0315  0.0296
# 2013-10  0.0461  0.0625  0.0535  0.0455  ...  0.0539  0.0392  0.0331  0.0364
# 2013-11  0.0152  0.0115 -0.0242  0.0313  ...  0.0372  0.0320  0.0606  0.0172
# ...

# %%
l=["Books","Steel","Oil","Mines"]
n=er[l].shape[0]

# %%
import numpy as np
w_ew= np.repeat(1/n,n)

# %%
w_ew
# Out:
# array([0.25, 0.25, 0.25, 0.25])

# %%
erk.msr(0.1,er[l],cov.loc[l,l]).max()
# Out:
# 0.9999999999999953

# %%
erk.msr(0.1,er[l],cov.loc[l,l]).argmax()
# Out:
# 1

# %%
w_msr=erk.msr(0.1,er[l],cov.loc[l,l])
w_msr
# Out:
# array([4.51375048e-15, 1.00000000e+00, 1.40512602e-16, 0.00000000e+00])

# %%
l[1]
# Out:
# 'Steel'

# %%
w_gmv=erk.gmv(cov.loc[l,l])

# %%
w_gmv.max()
# Out:
# 0.47702487032166246

# %%
w_gmv.argmax()
# Out:
# 0

# %%
w_gmv
# Out:
# array([4.77024870e-01, 4.33680869e-19, 4.34112024e-01, 8.88631053e-02])

# %%
w_gmv[1]
# Out:
# 4.336808689942018e-19

# %%
ind=erk.get_ind_returns()["2018"]
ind.head()
# Out:
#            Food    Beer   Smoke   Games  ...   Rtail   Meals     Fin   Other
# 2018-01  0.0238 -0.0011  0.0013  0.1726  ...  0.1156  0.0323  0.0611  0.0551
# 2018-02 -0.0675 -0.0676 -0.0662  0.0109  ... -0.0472 -0.0419 -0.0255 -0.0444
# 2018-03 -0.0187  0.0127 -0.0165 -0.0017  ... -0.0325 -0.0054 -0.0338 -0.0340
# 2018-04 -0.0167 -0.0429 -0.1416  0.0331  ...  0.0429  0.0350  0.0118 -0.0190
# 2018-05 -0.0078 -0.0119 -0.0187  0.0902  ...  0.0136 -0.0195  0.0040 -0.0038
#
# [5 rows x 30 columns]

# %%
erk.portfolio_vol(w_gmv,ind[l].cov())*(12**0.5)
# Out:
# 0.18973734511535803

# %%
erk.portfolio_vol(w_msr,ind[l].cov())*(12**0.5)
# Out:
# 0.21983988181484135

# %%
ind[l].cov()
# Out:
#           Books     Steel       Oil     Mines
# Books  0.002799  0.002098  0.002558  0.001629
# Steel  0.002098  0.004027  0.003473  0.001843
# Oil    0.002558  0.003473  0.005296  0.001961
# Mines  0.001629  0.001843  0.001961  0.002059
